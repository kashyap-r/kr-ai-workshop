# %% [markdown]
# For PDF extraction
# Consider, pypdf
#
#
# Check what libraries are available to parge PDF
# which is the best one?
#
# Note: At this point, an open source library capable of reading the pdf is more than necessary.
